# %% [raw]
# #EDA
# -- Profile of data
# -- statastics based analysis
# -- Graph based analysis

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
df.sample(5)
# Out:
#                                                  App  Category  Rating  \
# 112    Selfie Camera Photo Editor & Filter & Sticker    BEAUTY     4.1
# 5190                     ParaTek Ai Speech generator     TOOLS     3.6
# 5534                                         Ingress      GAME     4.3
# 5560                  Augment - 3D Augmented Reality  BUSINESS     4.1
# 10295                                    Sports Lite    SPORTS     4.4
#
#       Reviews  Size     Installs  Type Price Content Rating     Genres  \
# 112       187   30M      50,000+  Free     0           Teen     Beauty
# 5190      448  4.3M      50,000+  Free     0       Everyone      Tools
# 5534   391325   43M  10,000,000+  Free     0       Everyone  Adventure
# 5560    25195   21M   1,000,000+  Free     0       Everyone   Business
# 10295      16  4.9M       1,000+  Free     0       Everyone     Sports
#
#             Last Updated Current Ver   Android Ver
# 112        July 24, 2018       3.0.1  4.0.3 and up
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.describe(include = 'all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10836      Everyone
# 10837      Everyone
# 10838      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 10841, dtype: object

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy = df.copy()
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.drop(df_copy.index[10472])
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#drop multiple row -> iloc
df_copy.iloc[:,-1] #implicit index
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10836            4.1 and up
# 10837            4.1 and up
# 10838            2.2 and up
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10841, dtype: object

# %%
df_copy.Reviews.dtype
# Out:
# dtype('O')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df_copy["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
#Conversion
#MB = 1024 kb

# %%
# $replace
df_copy["Size"] = df_copy["Size"].str.replace("M", "000")
df_copy["Size"] = df_copy["Size"].str.replace("k", "")

# %%
df_copy["Size"]
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10836                 53000
# 10837                3.6000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10841, dtype: object

# %%
import numpy as np
df_copy["Size"] = df_copy["Size"].str.replace("Varies with device",str(np.nan))
df_copy["Size"] = df_copy["Size"].str.replace("+", "1")
df_copy["Size"] = df_copy["Size"].str.replace(",", "")
# Out:
# /tmp/ipykernel_134/4008848437.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copy["Size"] = df_copy["Size"].str.replace("+", "1")

# %%
df_copy["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df_copy["Size"] = df_copy["Size"].astype("float")

# %%
df_copy["Size"].dtype
# Out:
# dtype('float64')

# %%
df_copy["Size"][2]
# Out:
# 8.7

# %%
for i in df_copy["Size"]:
    if i< 10:
        df_copy["Size"].replace(i , i*1000)
df_copy["Size"]
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10841, dtype: float64

# %%
df_copy_size = df_copy["Size"]/1000

# %%
df_copy_size
# Out:
# 0        19.0000
# 1        14.0000
# 2         0.0087
# 3        25.0000
# 4         0.0028
#           ...
# 10836    53.0000
# 10837     0.0036
# 10838     0.0095
# 10839        NaN
# 10840    19.0000
# Name: Size, Length: 10841, dtype: float64

# %%
#10.2 -> algo

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            9146 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
df_copy["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
df_copy["Installs"] = df_copy["Installs"].str.replace('+',"").str.replace(",","")
# Out:
# /tmp/ipykernel_134/3257967707.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copy["Installs"] = df_copy["Installs"].str.replace('+',"").str.replace(",","")

# %%
df_copy["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
char_remove = ['+','$',',' ,'Everyone','Free']

cols_clean = ['Installs','Price']
for char in char_remove:
    for col in cols_clean:
        df_copy[col] = df_copy[col].str.replace(char, "")
        
# df_copy["Price"] = df_copy["Price"].str.replace('','0')


# Assuming you have a DataFrame named 'df' with an 'Install' column
# Replace 'your_column_name' with the actual column name you want to check

df_copy = df_copy[df_copy['Installs'] != '']
# Out:
# /tmp/ipykernel_134/879461770.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copy[col] = df_copy[col].str.replace(char, "")

# %%
 df_copy['Price'].dropna(inplace = True)
df_copy['Installs'].dropna(inplace = True)
# Out:
# /tmp/ipykernel_134/3023873657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['Price'].dropna(inplace = True)
# /tmp/ipykernel_134/3023873657.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['Installs'].dropna(inplace = True)

# %%
# df_copy["Installs"] = df_copy["Installs"].astype("int")
# df_copy["Price"] = df_copy["Price"].astype("int")

# %%
df_copy["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_copy["Installs"] = df_copy["Installs"].astype("int")
df_copy["Price"] = df_copy["Price"].astype("float")
# Out:
# /tmp/ipykernel_134/3494552620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy["Installs"] = df_copy["Installs"].astype("int")
# /tmp/ipykernel_134/3494552620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy["Price"] = df_copy["Price"].astype("float")

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df_copy['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
df_copy['Last Updated'] = pd.to_datetime(df_copy['Last Updated'])
# Out:
# /tmp/ipykernel_134/3621967408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['Last Updated'] = pd.to_datetime(df_copy['Last Updated'])

# %%
df_copy['day'] = df_copy['Last Updated'].dt.day
df_copy['month'] = df_copy['Last Updated'].dt.month
df_copy['year'] = df_copy['Last Updated'].dt.year
# Out:
# /tmp/ipykernel_134/674382388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['day'] = df_copy['Last Updated'].dt.day
# /tmp/ipykernel_134/674382388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['month'] = df_copy['Last Updated'].dt.month
# /tmp/ipykernel_134/674382388.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_copy.drop('Last Updated', inplace = True, axis = 1)
# Out:
# /tmp/ipykernel_134/1996298263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop('Last Updated', inplace = True, axis = 1)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Current Ver     10832 non-null  object
#  11  Android Ver     10838 non-null  object
#  12  day             10840 non-null  int64
#  13  month           10840 non-null  int64
#  14  year            10840 non-null  int64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df_copy["Android Ver"].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("and up", "").str.replace("Varies with device","")
# Out:
# /tmp/ipykernel_134/1199153302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("and up", "").str.replace("Varies with device","")

# %%
 df_copy["Android Ver"].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        '', '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ', '2.1 ', '7.0 ', '5.1 ',
#        '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ', '4.4W ', '7.1 ',
#        '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ', '2.0.1 ',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
df_copy.App
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10840, dtype: object

# %%
df_copy[df_copy.duplicated("App")]
# Out:
#                                       App       Category  Rating Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2   80805
# 236                                   Box       BUSINESS     4.2  159872
# 239                    Google My Business       BUSINESS     4.4   70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4   31614
# 261             join.me - Simple Meetings       BUSINESS     4.0    6989
# ...                                   ...            ...     ...     ...
# 10715                  FarmersOnly Dating         DATING     3.0    1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4   36981
# 10730                         FP Notebook        MEDICAL     4.5     410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5   33599
# 10768                                AAFP        MEDICAL     3.8      63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
df.drop_duplicates(subset = ["App"], keep = "first") #keeping the first value droping others
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# EDA

# %%
numeric_features = [feature for feature in df_copy if df_copy[feature].dtype != 'O']
categorical_features = [feature for feature in df_copy if df_copy[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
df_copy[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#ANlyze categorical features
df_copy["Type"].value_counts(normalize = True) * 100
# Out:
# Free    92.619245
# Paid     7.380755
# Name: Type, dtype: float64

# %%
#ANlyze categorical features
df_copy["Android Ver"].value_counts(normalize = True) * 100
# Out:
# 4.1              22.614874
# 4.0.3            13.849419
# 4.0              12.686843
#                  12.566894
# 4.4               9.042259
# 2.3               6.015870
# 5.0               5.545304
# 4.2               3.635357
# 2.3.3             2.592729
# 2.2               2.251338
# 4.3               2.242111
# 3.0               2.223658
# 2.1               1.236390
# 1.6               1.070308
# 6.0               0.553608
# 7.0               0.387525
# 3.2               0.332165
# 2.0               0.295257
# 5.1               0.221443
# 1.5               0.184536
# 4.4W              0.110722
# 3.1               0.092268
# 2.0.1             0.064588
# 8.0               0.055361
# 7.1               0.027680
# 4.0.3 - 7.1.1     0.018454
# 5.0 - 8.0         0.018454
# 1.0               0.018454
# 7.0 - 7.1.1       0.009227
# 4.1 - 7.1.1       0.009227
# 5.0 - 6.0         0.009227
# 2.2 - 7.1.1       0.009227
# 5.0 - 7.1.1       0.009227
# Name: Android Ver, dtype: float64

# %%
#for all coumns
for col in categorical_features:
    print(f"{col},>>>>> : {df_copy[col].value_counts(normalize = True)* 100}")  
    print(10 * ">>>>>>")
# Out:
# App,>>>>> : ROBLOX                                                0.083026
# CBS Sports App - Scores, News, Stats & Watch Live     0.073801
# ESPN                                                  0.064576
# Duolingo: Learn Languages Free                        0.064576
# Candy Crush Saga                                      0.064576
#                                                         ...
# Meet U - Get Friends for Snapchat, Kik & Instagram    0.009225
# U-Report                                              0.009225
# U of I Community Credit Union                         0.009225
# Waiting For U Launcher Theme                          0.009225
# iHoroscope - 2018 Daily Horoscope & Astrology         0.009225
# Name: App, Length: 9659, dtype: float64
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Category,>>>>> : FAMILY                 18.191882
# GAME                   10.553506
# TOOLS                   7.776753
# MEDICAL                 4.271218
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x = df_copy["Type"])
# Out:
# <AxesSubplot: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x = df_copy["Content Rating"])
# Out:
# <AxesSubplot: xlabel='Content Rating', ylabel='count'>

# %%
numeric_features
# Out:
# ['Rating', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.distplot(df_copy["Rating"])
# Out:
# /tmp/ipykernel_134/1127234466.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_copy["Rating"])
# <AxesSubplot: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(x = df_copy["Rating"])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Density'>

# %%
import matplotlib.pyplot as plt


plt.figure(figsize = (20,15))
# plt.subtitle("Univeriate analysis for cat feature")
category = ["Type","Content Rating", 'Installs']
for i in range(0, len(category)):
    plt.subplot(2, 2 , i+1)
    sns.countplot(x = df_copy[category[i]],palette = "Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation = 45)
    # plt.tight_layout() // compact

# %%
df_copy["Category"].value_counts().plot.pie(y= df_copy["Category"], figsize = (12,12))
# Out:
# <AxesSubplot: ylabel='Category'>

# %%
#percentage in plot 
df_copy["Category"].value_counts().plot.pie(y= df_copy["Category"], figsize = (12,12), autopct = '%1.1f')
# Out:
# <AxesSubplot: ylabel='Category'>

# %% [markdown]
# # Complex analysis

# %%
# want top 10 catgeory

# %%
cat = df_copy["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(cat)

# %%
category
# Out:
#                  Category
# FAMILY               1972
# GAME                 1144
# TOOLS                 843
# MEDICAL               463
# BUSINESS              460
# PRODUCTIVITY          424
# PERSONALIZATION       392
# COMMUNICATION         387
# SPORTS                384
# LIFESTYLE             382

# %%
sns.barplot(category , x= category.index , y = category['Category'] )
# Out:
# <AxesSubplot: ylabel='Category'>

# %%
#WHich category has highest installs

# %%
df_copy.groupby(['Category', 'Type'])['Installs'].sum().sort_values(ascending = False).reset_index()
# Out:
#               Category  Type     Installs
# 0                 GAME  Free  35064924450
# 1        COMMUNICATION  Free  32645916201
# 2         PRODUCTIVITY  Free  14174679314
# 3               SOCIAL  Free  14069861902
# 4                TOOLS  Free  11451044474
# ..                 ...   ...          ...
# 58            SHOPPING  Paid        10100
# 59              SOCIAL  Paid         6000
# 60  NEWS_AND_MAGAZINES  Paid         5500
# 61  LIBRARIES_AND_DEMO  Paid          100
# 62              EVENTS  Paid            1
#
# [63 rows x 3 columns]

# %%
# What are top 5 installed apps in each popular category

df_temp = df_copy.groupby(['Category', 'App', 'Type'])['Installs'].sum().sort_values(ascending = False).reset_index()

# %%
df_temp[df_temp.Type == 'Free']
# Out:
#                 Category                     App  Type    Installs
# 0                   GAME          Subway Surfers  Free  6000000000
# 1            PHOTOGRAPHY           Google Photos  Free  4000000000
# 2                 SOCIAL               Instagram  Free  4000000000
# 3          COMMUNICATION                Hangouts  Free  4000000000
# 4           PRODUCTIVITY            Google Drive  Free  4000000000
# ...                  ...                     ...   ...         ...
# 9729              SPORTS      FK Bregalnica Štip  Free           1
# 9732      ART_AND_DESIGN  Test Application DT 02  Free           0
# 9734              SOCIAL           Pekalongan CJ  Free           0
# 9739  NEWS_AND_MAGAZINES       Sweden Newspapers  Free           0
# 9741            BUSINESS              CX Network  Free           0
#
# [8986 rows x 4 columns]

# %%
df_temp[df_temp.Category == "Game"]
# Out:
# Empty DataFrame
# Columns: [Category, App, Type, Installs]
# Index: []

# %%
#Which category app user are review the most
df_copy.groupby(['Category', 'App'])['Reviews'].sum().sort_values(ascending = False).reset_index()
# Out:
#                 Category                                App   Reviews
# 0                 SPORTS             GollerCepte Live Score      9992
# 1                  TOOLS       Ad Block REMOVER - NEED ROOT       999
# 2               SHOPPING                SnipSnap Coupon App  99759975
# 3                 SPORTS  US Open Tennis Championships 2018  99719971
# 4       TRAVEL_AND_LOCAL                         DreamTrips      9971
# ...                  ...                                ...       ...
# 9739       COMMUNICATION              Hyundai CX Conference         0
# 9740       COMMUNICATION                 Hlášenírozhlasu.cz         0
# 9741        PRODUCTIVITY              CE SODEXO PASS FRANCE         0
# 9742  HEALTH_AND_FITNESS                       Bodyworks DW         0
# 9743  HEALTH_AND_FITNESS                 Cy's Elma Pharmacy         0
#
# [9744 rows x 3 columns]

# %%
#Which category app user are review the most
df_copy.groupby(['Category', 'App']).agg({"Reviews":"sum", "Installs":"sum"})
# Out:
#                                                                         Reviews  \
# Category       App
# ART_AND_DESIGN 350 Diy Room Decor Ideas                                      27
#                3D Color Pixel by Number - Sandbox Art Coloring             1518
#                AJ Styles HD Wallpapers                                       48
#                AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper             18
#                Ai illustrator viewer                                        486
# ...                                                                         ...
# WEATHER        Yahoo Weather                                            1312037
#                Yahoo! Weather for SH Forecast for understandin...          7457
#                Yandex.Weather                                            309617
#                weather - weather forecast                                 11118
# ...

# %%
# HOw many apps are Greater than 5 Rating

# %%
# HOw many apps are Greater than 5 Rating for each category

# %%
#2 feature at a
